# %%
import requests
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
from selenium.webdriver.chrome.options import Options
from skimage.feature import local_binary_pattern
import cv2
import numpy as np

# %%
url_dict ={
    "bellanaija": ["https://www.bellanaija.com/2025/11/lagos-fashion-week-2025-see-emmy-kasbits-collection/"]
    }

# %%
driver = webdriver.Chrome()

for web_page, urls in url_dict.items():
    folder = os.path.join('kasbit_fabric_images', web_page)
    if os.path.exists(folder):
        continue
    os.makedirs(folder, exist_ok=True)

    for url in urls:
        driver.get(url)
        time.sleep(15)

        elements = driver.find_elements(By.TAG_NAME, 'img')
        print(f"Found {len(elements)} image elements.")

        count = 0
        for index, img in enumerate(elements):
            src = img.get_attribute('src')
            if src and src.startswith("http"):
                try:
                    img_data = requests.get(src).content
                    filename = f"{'kasbit'}_{web_page}_{index+1}.jpg"
                    path = os.path.join(folder, filename)
                    with open((path), 'wb') as f:
                        f.write(img_data)
                except Exception as e:
                    print(f"Error downloading image {src}: {e}")
                    continue
        

driver.quit()
print("All Images from all websites downloaded.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 driver = webdriver.Chrome()
#       3 for web_page, urls in url_dict.items():
#       4     folder = os.path.join('kasbit_fabric_images', web_page)
#
# File c:\Users\User\OneDrive\Desktop\Lagos-FW-2024-Analysis\Lagos-FW-2024-Analysis-1\fw_env\lib\site-packages\selenium\webdriver\chrome\webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# File c:\Users\User\OneDrive\Desktop\Lagos-FW-2024-Analysis\Lagos-FW-2024-Analysis-1\fw_env\lib\site-packages\selenium\webdriver\chromium\webdriver.py:55, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 options = options if options else ChromiumOptions()
#      54 finder = DriverFinder(self.service, options)
# ---> 55 if finder.get_browser_path():
#      56     options.binary_location = finder.get_browser_path()
#      57     options.browser_version = None
#
# File c:\Users\User\OneDrive\Desktop\Lagos-FW-2024-Analysis\Lagos-FW-2024-Analysis-1\fw_env\lib\site-packages\selenium\webdriver\common\driver_finder.py:48, in DriverFinder.get_browser_path(self)
#      47 def get_browser_path(self) -> str:
# ---> 48     return self._binary_paths()["browser_path"]
#
# File c:\Users\User\OneDrive\Desktop\Lagos-FW-2024-Analysis\Lagos-FW-2024-Analysis-1\fw_env\lib\site-packages\selenium\webdriver\common\driver_finder.py:68, in DriverFinder._binary_paths(self)
#      66     self._paths["driver_path"] = path
#      67 else:
# ---> 68     output = SeleniumManager().binary_paths(self._to_args())
#      69     if Path(output["driver_path"]).is_file():
#      70         self._paths["driver_path"] = output["driver_path"]
#
# File c:\Users\User\OneDrive\Desktop\Lagos-FW-2024-Analysis\Lagos-FW-2024-Analysis-1\fw_env\lib\site-packages\selenium\webdriver\common\selenium_manager.py:56, in SeleniumManager.binary_paths(self, args)
#      53 args.append("--output")
#      54 args.append("json")
# ---> 56 return self._run(args)
#
# File c:\Users\User\OneDrive\Desktop\Lagos-FW-2024-Analysis\Lagos-FW-2024-Analysis-1\fw_env\lib\site-packages\selenium\webdriver\common\selenium_manager.py:122, in SeleniumManager._run(args)
#     120 try:
#     121     if sys.platform == "win32":
# --> 122         completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     123     else:
#     124         completed_proc = subprocess.run(args, capture_output=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1544, in Popen._communicate(self, input, endtime, orig_timeout)
#    1540 # Wait for the reader threads, or time out.  If we time out, the
#    1541 # threads remain reading and the fds left open in case the user
#    1542 # calls communicate again.
#    1543 if self.stdout is not None:
# -> 1544     self.stdout_thread.join(self._remaining_time(endtime))
#    1545     if self.stdout_thread.is_alive():
#    1546         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
